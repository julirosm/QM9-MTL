# %%
import torch
import torch.nn.functional as F

from nn.models import Singletasking
from utils.graph_utils import load_qm9_dataset, create_properties_dict
from utils.training_utils import create_dataloaders, train_model, Multitasking_Loss, evaluate
from utils.plot_utils import plot_training_curves, plot_predictions_vs_real

# %%
folder = "/home/julian-ros/Desktop/QM9/Datasets/processed/dataset_cluster_v4"
target = 9
properties_dict = create_properties_dict()

dataset = load_qm9_dataset(folder_path=folder,
            atom_properties=['group', 'period','electron_affinity', 'electronegativity', "covalent_radius_cordero", 'mass_number'],
            OH_node_features = [0,1], minmax_node_features = [2,3,4,5],
            normalize=True,
            r_max=5.0,
            energy_units = "eV",
            return_stats=False,
            target = target)
# Out:
# Total number of samples: 133885.
# /home/julian-ros/anaconda3/envs/E3nn_temp/lib/python3.9/site-packages/torch_geometric/data/in_memory_dataset.py:300: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)

# %%
# Create dataloaders
n_train = int(len(dataset)*0.8)
n_valid = int(len(dataset)*0.1)
n_test = len(dataset) - n_train - n_valid
train_loader, valid_loader, test_loader = create_dataloaders(dataset=dataset, batch_size=64, n_train = n_train, n_valid = n_valid, n_test = n_test, seed=123)
# Out:
# Dataloaders created with 107108 training samples, 13388 validation samples and 13389 testing samples

# %%
x_dim = dataset[0].x.size(dim=1)
z_dim = dataset[0].z.size(dim=1)

model = Singletasking(
    x_dim=x_dim,
    z_dim=z_dim,
    emb_dim=32,
    target=target,
    l_max=1,
    layers=3,
    max_radius=5.0,
    number_of_basis=84,
    radial_layers=2,
    radial_neurons=100,
    mlp_layers=2,
    mlp_neurons=128,
)
print(model)
# Out:
# Singletasking(
#   (graph_preprocessing): Graph_Preprocessing()
#   (x_emb): Linear(in_features=11, out_features=32, bias=True)
#   (z_emb): Linear(in_features=10, out_features=32, bias=True)
#   (ext_z): ExtractIr(
#     (_compiled_forward): RecursiveScriptModule(original_name=GraphModule)
#   )
#   (backbone): Equivariant_module(
#     (equivariant_layers): ModuleList(
#       (0): Equivariant_layer(
#         (gate): Gate (64x0e+32x1o -> 32x0e+32x1o)
#         (conv): Convolution(
#           (sc): FullyConnectedTensorProduct(32x0e x 32x0e -> 64x0e+32x1o | 65536 paths | 65536 weights)
#           (lin1): FullyConnectedTensorProduct(32x0e x 32x0e -> 32x0e | 32768 paths | 32768 weights)
#           (fc): FullyConnectedNet[148, 100, 100, 64]
#           (tp): TensorProduct(32x0e x 1x0e+1x1o -> 32x0e+32x1o | 64 paths | 64 weights)
#           (lin2): FullyConnectedTensorProduct(32x0e+32x1o x 32x0e -> 64x0e+32x1o | 98304 paths | 98304 weights)
#         )
#       )
#       (1): Equivariant_layer(
#         (gate): Gate (64x0e+32x1o -> 32x0e+32x1o)
#         (conv): Convolution(
#           (sc): FullyConnectedTensorProduct(32x0e+32x1o x 32x0e -> 64x0e+32x1o | 98304 paths | 98304 weights)
#           (lin1): FullyConnectedTensorProduct(32x0e+32x1o x 32x0e -> 32x0e+32x1o | 65536 paths | 65536 weights)
#           (fc): FullyConnectedNet[148, 100, 100, 128]
#           (tp): TensorProduct(32x0e+32x1o x 1x0e+1x1o -> 64x0e+64x1o | 128 paths | 128 weights)
#           (lin2): FullyConnectedTensorProduct(64x0e+64x1o x 32x0e -> 64x0e+32x1o | 196608 paths | 196608 weights)
#         )
#       )
#       (2): Equivariant_layer(
#         (gate): Gate (32x0e -> 32x0e)
#         (conv): Convolution(
#           (sc): FullyConnectedTensorProduct(32x0e+32x1o x 32x0e -> 32x0e | 32768 paths | 32768 weights)
#           (lin1): FullyConnectedTensorProduct(32x0e+32x1o x 32x0e -> 32x0e+32x1o | 65536 paths | 65536 weights)
#           (fc): FullyConnectedNet[148, 100, 100, 64]
#           (tp): TensorProduct(32x0e+32x1o x 1x0e+1x1o -> 64x0e | 64 paths | 64 weights)
#           (lin2): FullyConnectedTensorProduct(64x0e x 32x0e -> 32x0e | 65536 paths | 65536 weights)
#         )
#       )
#     )
#   )
#   (out): Extensive(
#     (mlp): MLP(
#       (network): Sequential(
#         (0): Linear(in_features=32, out_features=128, bias=True)
#         (1): SiLU()
#         (2): Linear(in_features=128, out_features=1, bias=True)
#       )
#     )
#   )
# )

# %%
lr = 1e-3
weight_decay = 3.5*1e-6
epochs=250
criterion = Multitasking_Loss(F.mse_loss)
train_loss, valid_loss, weighted_losses, weighted_val_losses = train_model(model, 
                                                                            target=target,
                                                                            train_loader=train_loader, valid_loader=valid_loader,
                                                                            epochs=epochs, scheduler="cosine",
                                                                            criterion=criterion,
                                                                            lr=lr, weight_decay=weight_decay,
                                                                            early_stopping_patience=30)
# Out:
# Visible CPUs: 12
# PyTorch: 6 used threads
# [Used RAM] 1.65 GB
# Total parameters: 825985
#
# Start training:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 5
#       3 epochs=250
#       4 criterion = Multitasking_Loss(F.mse_loss)
# ----> 5 train_loss, valid_loss, weighted_losses, weighted_val_losses = train_model(model,
#       6                                                                             target=target,
#       7                                                                             train_loader=train_loader, valid_loader=valid_loader,
#       8                                                                             epochs=epochs, scheduler="cosine",
#       9                                                                             criterion=criterion,
#      10                                                                             lr=lr, weight_decay=weight_decay,
#      11                                                                             early_stopping_patience=30)
#
# File ~/Desktop/Future GitHub/Multitasking_v4/utils/training_utils.py:240, in train_model(model, target, train_loader, valid_loader, criterion, epochs, lr, weight_decay, scheduler, scheduler_kwargs, device, loss_weights, early_stopping_patience, checkpoint_path)
#     238 train_loss = torch.zeros(model.out_channels, device=device)
#     239 for data in train_loader:
# --> 240     losses = train(model, data, optimizer, criterion, loss_normalization, loss_weights, device)
#     241     train_loss += losses.detach().view(-1)
#     242     # Onecycle step
#
# File ~/Desktop/Future GitHub/Multitasking_v4/utils/training_utils.py:82, in train(model, data, optimizer, criterion, loss_normalization, weights, device)
#      80 losses = criterion(y_pred.view(-1,model.out_channels), data.y.view(-1,model.out_channels))/loss_normalization
#      81 weighted_loss = compute_weighted_loss(losses, weights)
# ---> 82 weighted_loss.backward()
#      83 # torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=10.0)
#      84 optimizer.step()
#
# File ~/anaconda3/envs/E3nn_temp/lib/python3.9/site-packages/torch/_tensor.py:521, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     511 if has_torch_function_unary(self):
#     512     return handle_torch_function(
#     513         Tensor.backward,
#     514         (self,),
#    (...)
#     519         inputs=inputs,
#     520     )
# --> 521 torch.autograd.backward(
#     522     self, gradient, retain_graph, create_graph, inputs=inputs
#     523 )
#
# File ~/anaconda3/envs/E3nn_temp/lib/python3.9/site-packages/torch/autograd/__init__.py:289, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     284     retain_graph = create_graph
#     286 # The reason we repeat the same comment below is that
#     287 # some Python versions print out the first line of a multi-line function
#     288 # calls in the traceback and some print out the last line
# --> 289 _engine_run_backward(
#     290     tensors,
#     291     grad_tensors_,
#     292     retain_graph,
#     293     create_graph,
#     294     inputs,
#     295     allow_unreachable=True,
#     296     accumulate_grad=True,
#     297 )
#
# File ~/anaconda3/envs/E3nn_temp/lib/python3.9/site-packages/torch/autograd/graph.py:769, in _engine_run_backward(t_outputs, *args, **kwargs)
#     767     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     768 try:
# --> 769     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     770         t_outputs, *args, **kwargs
#     771     )  # Calls into the C++ engine to run the backward pass
#     772 finally:
#     773     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
title = f"Training curve for property {properties_dict[target]['Description']}"
save_path = f"./plots/training_curve.png"
plot_training_curves(train_loss, valid_loss, log_scale=True, 
                        title=title, save_path=save_path)
# Out:
# Plot saved to: ./plots/training_curve.png

# %%
# Evaluation
device = 'cuda' if torch.cuda.is_available() else "cpu"
test_loss, test_mae, real_values, predictions = evaluate(model, test_loader, criterion, device, return_predictions=True)
print(f"Property: {properties_dict[target]['Description']}, "
      f"Test Loss: {test_loss[0]:.6f}, Test MAE:{test_mae[0]:.6f} {properties_dict[target]['Unit']}")
# XY plot
title = f"Predictions for {properties_dict[target]['Description']}"
save_path = f"./plots/predictions.png"
plot_predictions_vs_real(real_values=real_values,predictions=predictions, 
                            title=title, save_path=save_path)
# Out:
# Property: Dipole moment, Test Loss: 3.262149, Test MAE:1.806142 D
# Plot saved to: ./plots/predictions.png

# %%
test_mae
# Out:
# tensor([1.8061])
